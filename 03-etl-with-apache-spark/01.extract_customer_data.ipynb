# %%
# %sql
select * from json.`/Volumes/tabular/dataexpert/anallasw/project_gizmobox/landing/operational_data/customers/`

# %% [markdown]
# ### Create View in the bronze layer for customers data

# %%
# %sql
create or replace view tabular.dataexpert.bronze_anallasw_dea_customers as
select * from json.`/Volumes/tabular/dataexpert/anallasw/project_gizmobox/landing/operational_data/customers/`

# %%
# %sql
select * from json.`/Volumes/tabular/dataexpert/anallasw/project_gizmobox/landing/operational_data/customers/customers_2024_*.json`

# %% [markdown]
# ## Select File metadata

# %% [markdown]
# select input_file_name() as file_path,* --------Deprecated from 13.3 LTs onwards
# from json.`/Volumes/tabular/dataexpert/anallasw/project_gizmobox/landing/operational_data/customers/`

# %%
# %sql
select _metadata.file_path() as file_path,*
from json.`/Volumes/tabular/dataexpert/anallasw/project_gizmobox/landing/operational_data/customers/`
